# %%
print("Mamba Mentality")

# %%
# %sql
CREATE VOLUME IF NOT EXISTS project.raw.rawdata

# %%
dbutils.fs.mkdirs("/Volumes/project/raw/rawdata/rawsrc/airports")

# %%
# %sql
SELECT * FROM delta.`/Volumes/project/bronze/bronzevolume/bookings/data`
